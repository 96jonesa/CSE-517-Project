# %% [markdown]
# <a href="https://colab.research.google.com/github/96jonesa/CSE-517-Project/blob/main/newscaffolding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Imports

# %%
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %% [markdown]
# #GRU

# %% [markdown]
# ##GRU
# This is just a wrapper around nn.GRU for the sake of consistency. Used in the Price Encoder, day-level SMI Encoder, and temporal SMI Encoder.

# %%
class GRU(nn.Module):
    def __init__(self, input_size, hidden_size, batch_first=False):
        super(GRU, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.batch_first = batch_first

        self.gru = nn.GRU(input_size, hidden_size, batch_first=self.batch_first)

    def forward(self, input):
        output, hn = self.gru(input)
        return output, hn

# %% [markdown]
# #Self-Attention

# %% [markdown]
# ##LinearAttention
# The attention mechanism used in Feng et. al. Used in the Price Encoder, day-level SMI Encoder, and temporal SMI Encoder. Given input $h$, returns
# $q_t = \sum_{i=t-T}^T \beta_i h_i$ where $\beta_i = \dfrac{\exp\left( u^T \tanh \left( W h_i + b \right) \right)}{\sum_{k=t-T}^t \exp\left( u^T \tanh \left( W h_k + b \right) \right)}$.

# %%
# attention weights are softmax(u^T tanh(W input + b)) where W is learned parameter matrix, u is a learned parameter vector, and b is a learned offset

class LinearAttention(nn.Module):
    def __init__(self, input_size, intermediate_size, weights_size):
        super(LinearAttention, self).__init__()
        self.input_size = input_size
        self.intermediate_size = intermediate_size
        self.weights_size = weights_size

        self.linear_1 = nn.Linear(self.input_size, self.intermediate_size, bias=True)
        self.linear_2 = nn.Linear(self.intermediate_size, self.weights_size, bias=False)
        self.tanh = nn.Tanh()
        self.softmax = nn.Softmax(dim=2)

    def forward(self, input):
        intermediate = self.tanh(self.linear_1(input))
        attention_weights = self.softmax(self.linear_2(intermediate))
        attention_weights = attention_weights.permute(0, 2, 1)
        output_features = torch.bmm(attention_weights, input)

        return output_features

# %% [markdown]
# #Blending

# %% [markdown]
# ##Blend
# Applies a learned bilinear transformation to the left and right vectors, then inputs the result to a ReLU non-linearity. Used to obtain Multi-Modal Encodings from Price Encodings and temporal SMI Encodings. Given Price Encodings $q_t$ and temporal SMI Encodings $c_t$, returns
# $x_t = \mathcal{B} \left( c_t, q_t \right) = \text{ReLU} \left( q_t^T W c_t + b \right)$.

# %%
# output is ReLU(left^T W right + b) where W is a learned paramater matrix
# and b is a learned bias

class Blend(nn.Module):
    def __init__(self, left_size, right_size, output_size):
        super(Blend, self).__init__()
        self.left_size = left_size
        self.right_size = right_size
        self.output_size = output_size

        self.bilinear = nn.Bilinear(self.left_size, self.right_size, output_size, bias=True)
        self.relu = nn.ReLU()
    
    def forward(self, left, right):
        output = self.relu(self.bilinear(left, right))

        return output

# %% [markdown]
# #Single-Headed Graph Attention Network (SGAT)

# %% [markdown]
# ##SharedLinear
# This is just a wrapper around nn.Linear for the sake of consistency. Used to apply a shared linear transformation to all inputs of an SGAT layer. Under current implementation, this should be applied before passing inputs to SGAT.

# %%
# need shared learned parameter matrix W to multiply against each input vector

class SharedLinear(nn.Module):
    def __init__(self, input_size, output_size):
        super(SharedLinear, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        
        self.linear = nn.Linear(input_size, output_size, bias=False)
    
    def forward(self, input):
        output = self.linear(input)

        return output

# %% [markdown]
# ##SGAT
# A single-headed GAT layer. A shared linear transform $W$ is applied to all the nodes *before* passing them as input to this module (by passing them as input to a SharedLinear layer), then a shared self-attention mechanism is applied to each node $i$ in its immediate neighborhood $\mathcal{N}_i$. For each node $j\in \mathcal{N}_i$, normalized attention coefficients $\alpha_{i,j}$ are computed to represent the importance of the relations between stocks $i$ and $j$. That is,
# $\alpha_{i,j} = \dfrac{\exp ( \text{LeakyReLU} ( a_w^T [ W x_i
# \oplus W x_j ] ) )}{\sum_{k\in \mathcal{N}_i} \exp ( \text{LeakyReLU} ( a_w^T [ W x_i \oplus W x_k ] ) )}$
# where $\oplus$ denotes concatenation and $a_w$ is a learned parameter matrix. An updated feature vector $z_i$ for the $i$-th stock is computed by applying these attention weights to the linearly transformed multi-modal feature vectors of all of the stocks in $\mathcal{N}_i$

# %%
# merge code with MGAT code to form general case GAT code

class SGAT(nn.Module):
    def __init__(self, input_size, weights_size, leakyrelu_slope=0.01):
        super(SGAT, self).__init__()
        self.input_size = input_size
        self.weights_size = weights_size
        self.leakyrelu_slope = leakyrelu_slope
        
        self.linear = nn.Linear(2 * input_size, weights_size, bias=False)
        self.leakyrelu = nn.LeakyReLU(self.leakyrelu_slope)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, input, neighborhoods, index):
        stock = input[index]
        neighborhood = neighborhoods[index]
        stack_stock = stock.expand(len(neighborhood), stock.shape[0])
        stack_neighbors = input[neighborhood]
        cat_stock = torch.cat((stack_stock, stack_neighbors), dim=1)
        attention_weights = self.softmax(self.leakyrelu(self.linear(cat_stock)))  # check this
        output_features = torch.mm(attention_weights.T, stack_neighbors)  # check this

        return output_features

# %% [markdown]
# #MAN-SF

# %%
class MANSF(nn.Module):
    def __init__(self, T, num_stocks, gru_hidden_size, attn_inter_size, use_embed_size,
                 blend_size, gat_1_inter_size, gat_2_inter_size, leakyrelu_slope, elu_alpha, U):
        super(MANSF, self).__init__()
        #self.to(device)
        self.T = T
        self.num_stocks = num_stocks
        self.gru_hidden_size = gru_hidden_size
        self.attn_inter_size = attn_inter_size
        self.use_embed_size = use_embed_size
        self.blend_size = blend_size
        self.gat_1_inter_size = gat_1_inter_size
        self.gat_2_inter_size = gat_2_inter_size
        self.leakyrelu_slope = leakyrelu_slope
        self.elu_alpha = elu_alpha
        self.U = U

        self.gru_p = GRU(3, gru_hidden_size, batch_first=True)
        self.gru_m = GRU(use_embed_size, gru_hidden_size, batch_first=True)
        self.gru_s = GRU(gru_hidden_size, gru_hidden_size, batch_first=True)
        self.attn_p = LinearAttention(gru_hidden_size, attn_inter_size, 1)
        self.attn_m = LinearAttention(gru_hidden_size, attn_inter_size, 1)
        self.attn_s = LinearAttention(gru_hidden_size, attn_inter_size, 1)
        self.blend = Blend(gru_hidden_size, gru_hidden_size, blend_size)
        self.shared_linears_1 = nn.ModuleList([SharedLinear(blend_size, gat_1_inter_size) for u in range(U)])
        self.shared_linears_2 = nn.ModuleList([SharedLinear(U * gat_1_inter_size, gat_2_inter_size) for u in range(U)])
        self.mgat_1 = nn.ModuleList([nn.ModuleList([SGAT(gat_1_inter_size, 1, leakyrelu_slope=leakyrelu_slope) for i in range(num_stocks)]) for u in range(U)])
        self.mgat_2 = nn.ModuleList([nn.ModuleList([SGAT(gat_2_inter_size, 1, leakyrelu_slope=leakyrelu_slope) for i in range(num_stocks)]) for u in range(U)])
        #self.mgat_1 = []
        #for u in range(U):
            #sgats = []
            #for i in range(num_stocks):
                #sgats.append(SGAT(gat_1_inter_size, 1, leakyrelu_slope=leakyrelu_slope).to(device))
            #self.mgat_1.append(sgats)
            ##self.mgat_1.append(SGAT(gat_1_inter_size, 1, leakyrelu_slope=leakyrelu_slope))
        #self.mgat_2 = []
        #for u in range(U):
            #sgats = []
            #for i in range(num_stocks):
                #sgats.append(SGAT(gat_2_inter_size, 1, leakyrelu_slope=leakyrelu_slope).to(device))
            #self.mgat_2.append(sgats)
            ##self.mgat_2.append(SGAT(gat_2_inter_size, 1, leakyrelu_slope=leakyrelu_slope))
        self.sigmoid = nn.Sigmoid()
        self.elu = nn.ELU(elu_alpha)
        self.final_linear = nn.Linear(U * gat_2_inter_size, 1, bias=True)

    # p is price data tensor of shape (num_stocks, T, 3), for the day under consideration
    #
    # m is smi data list of tensors of shape (num_stocks, K, use_embed_size) of length T,
    #       where K is the number of tweets for the given stock on the day under consideration
    #
    # neighorhoods is a list of adjacency lists, where each stock is indexed with the same
    #       indices they have in p and m
    #
    # TODO: tensorize day-level smi
    # TODO: tensorize sgat 
    def forward(self, p, m, neighborhoods):
        ## price encoding
        h_p, _ = self.gru_p(p)
        q = self.attn_p(h_p)

        ## smi encoding (day level)
        r = torch.zeros(self.num_stocks, 0, self.gru_hidden_size)
        r = r.to(device)
        for t in range(self.T):
            h_m, _ = self.gru_m(m[t])
            r_t = self.attn_m(h_m)
            r = torch.cat((r, r_t), 1)

        ## smi encoding (aggregate)
        h_s, _ = self.gru_s(r)
        c = self.attn_s(h_s)

        ## blending
        x = self.blend(q, c)

        ## reshaping (eliminating superfluous dimension)
        x = x.view(x.shape[0], x.shape[2])

        ## first gat layer
        #  first head
        shared_linear = self.shared_linears_1[0]
        Wx = shared_linear(x)
        #sgat = self.mgat_1[0]
        sgat = self.mgat_1[0][0]
        z = sgat(Wx, neighborhoods, 0)
        z = self.elu(z)

        for i in range(1, self.num_stocks):
            sgat = self.mgat_1[0][i]  # this is the fix to the proceeding TODO
            z_i = sgat(Wx, neighborhoods, i)  # TODO: use fresh SGAT for each stock
            z_i = self.elu(z_i)
            z = torch.cat((z, z_i), 0)

        #  remaining heads
        for u in range(1, self.U):
            shared_linear = self.shared_linears_1[u]
            Wx = shared_linear(x)
            #sgat = self.mgat_1[u]
            sgat = self.mgat_1[u][0]
            z_u = sgat(Wx, neighborhoods, 0)
            z_u = self.elu(z_u)

            for i in range(1, self.num_stocks):
                sgat = self.mgat_1[u][i]
                z_u_i = sgat(Wx, neighborhoods, i)
                z_u_i = self.elu(z_u_i)
                z_u = torch.cat((z_u, z_u_i), 0)
            
            z = torch.cat((z, z_u), 1)
        
        ## second gat layer
        #  first head
        shared_linear = self.shared_linears_2[0]
        Wx = shared_linear(z)
        #sgat = self.mgat_2[0]
        sgat = self.mgat_2[0][0]
        new_z = sgat(Wx, neighborhoods, 0)
        new_z = self.sigmoid(new_z)

        for i in range(1, self.num_stocks):
            sgat = self.mgat_2[0][i]
            new_z_i = sgat(Wx, neighborhoods, i)
            new_z_i = self.sigmoid(new_z_i)
            new_z = torch.cat((new_z, new_z_i), 0)

        #  remaining heads
        for u in range(1, self.U):
            shared_linear = self.shared_linears_2[u]
            Wx = shared_linear(z)
            #sgat = self.mgat_2[u]
            sgat = self.mgat_2[u][0]
            new_z_u = sgat(Wx, neighborhoods, 0)
            new_z_u = self.sigmoid(new_z_u)

            for i in range(1, self.num_stocks):
                sgat = self.mgat_2[u][i]
                new_z_u_i = sgat(Wx, neighborhoods, i)
                new_z_u_i = self.sigmoid(new_z_u_i)
                new_z_u = torch.cat((new_z_u, new_z_u_i), 0)
            
            new_z = torch.cat((new_z, new_z_u), 1)
        
        ## final layer
        y = self.sigmoid(self.final_linear(new_z))

        ## return result
        return y

# %% [markdown]
# #Real Data Testing

# %%
# !pip3 install --quiet "tensorflow-hub>=0.7.0"
# !pip3 install --quiet seaborn

# %%
# !unzip /content/stocknet-dataset-master.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-03-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-04-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-05-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-06-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-07-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-08-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-09-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-10-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-11-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2014-12-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-01-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-02-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-03-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-04-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-05-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-06-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-07-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-08-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-09-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-10-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-11-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2015-12-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-01-31
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-13
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-14
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-02-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-01
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-02
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-03
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-04
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-05
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-06
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-07
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-08
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-09
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-10
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-11
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-12
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-15
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-16
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-17
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-18
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-19
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-20
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-21
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-22
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-23
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-24
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-25
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-26
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-27
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-28
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-29
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-30
#   inflating: stocknet-dataset-master/tweet/raw/T/2016-03-31
#    creating: stocknet-dataset-master/tweet/raw/TM/
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-01-02
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-01-03
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-01-09
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-01-14
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-01-15
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-01-16
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-01-21
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-01-24
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-01-25
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-02-03
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-02-04
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-02-07
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-02-08
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-02-10
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-02-13
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-02-21
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-03
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-05
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-08
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-11
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-12
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-16
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-19
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-20
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-21
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-23
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-25
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-26
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-03-27
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-09
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-10
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-12
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-15
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-16
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-19
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-20
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-21
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-22
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-23
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-24
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-27
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-28
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-04-29
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-05-07
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-05-10
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-05-13
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-05-15
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-05-16
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-05-21
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-05-22
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-05-23
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-05-24
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-05-26
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-05-29
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-06-02
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-06-04
#   inflating: stocknet-dataset-master/tweet/raw/TM/2014-06-05
# ...
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-05-31
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-01
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-02
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-03
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-06
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-07
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-08
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-09
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-10
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-11
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-12
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-13
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-14
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-15
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-16
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-18
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-19
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-20
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-21
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-24
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-25
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-27
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-28
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-06-29
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-01
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-02
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-03
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-04
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-05
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-06
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-10
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-11
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-12
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-13
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-15
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-16
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-19
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-20
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-21
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-22
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-23
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-24
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-25
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-27
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-29
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-30
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-07-31
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-01
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-02
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-03
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-05
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-06
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-07
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-08
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-10
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-11
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-12
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-13
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-14
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-17
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-18
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-20
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-21
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-24
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-25
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-26
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-27
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-29
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-30
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-08-31
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-01
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-02
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-04
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-05
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-06
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-08
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-09
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-10
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-11
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-12
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-13
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-14
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-15
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-19
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-20
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-22
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-23
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-24
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-25
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-26
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-27
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-28
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-29
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-09-30
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-01
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-02
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-04
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-05
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-06
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-07
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-08
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-09
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-10
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-11
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-12
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-13
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-14
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-15
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-16
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-17
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-18
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-19
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-20
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-21
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-22
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-23
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-24
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-25
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-26
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-27
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-28
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-29
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-30
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-10-31
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-01
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-02
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-03
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-04
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-05
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-06
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-07
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-08
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-09
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-10
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-11
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-12
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-13
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-14
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-15
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-16
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-18
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-19
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-20
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-22
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-23
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-24
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-25
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-26
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-28
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-11-29
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-01
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-02
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-04
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-05
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-06
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-08
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-09
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-10
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-11
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-12
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-15
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-21
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-22
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-23
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-24
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-25
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-26
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-28
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-29
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2015-12-30
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-01
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-02
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-03
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-04
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-05
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-06
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-07
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-08
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-09
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-10
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-11
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-12
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-13
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-14
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-15
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-16
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-17
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-18
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-19
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-20
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-21
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-22
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-23
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-24
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-25
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-27
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-28
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-29
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-30
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-01-31
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-01
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-02
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-03
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-04
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-05
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-06
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-07
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-08
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-09
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-10
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-11
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-12
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-13
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-14
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-15
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-16
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-17
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-18
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-19
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-20
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-21
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-22
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-23
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-24
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-25
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-26
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-27
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-02-28
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-01
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-02
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-03
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-04
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-05
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-06
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-07
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-08
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-09
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-10
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-11
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-12
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-15
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-16
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-17
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-23
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-24
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-25
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-28
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-29
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-30
#   inflating: stocknet-dataset-master/tweet/raw/XOM/2016-03-31

# %%
from absl import logging

import tensorflow.compat.v1 as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import re
import seaborn as sns
import json
import itertools
import pandas as pd
from tqdm import tqdm_notebook

# %%
module_url = "https://tfhub.dev/google/universal-sentence-encoder/2" #@param ["https://tfhub.dev/google/universal-sentence-encoder/2", "https://tfhub.dev/google/universal-sentence-encoder-large/3"]

# %%
tf.disable_v2_behavior()
tf.compat.v1.disable_eager_execution()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
stocknet_dataset_filepath = './stocknet-dataset-master'

# %%
preprocessed_prices_filepath = stocknet_dataset_filepath + '/price/preprocessed'
preprocessed_tweets_filepath = stocknet_dataset_filepath + '/tweet/preprocessed'

company_to_price_df = {}
company_to_tweets = {}

for filename in os.listdir(preprocessed_prices_filepath):
    with open(preprocessed_prices_filepath + '/' + filename) as file:
        company_name = filename.split('.')[0]
        
        # Not enough data for GMRE
        if company_name == 'GMRE':
            continue
        df = pd.read_csv(file, sep='\t')
        df.columns = ['date', 'open', 'high', 'low', 'close', 'adjust_close', 'volume']
        company_to_price_df[company_name] = df.dropna()

for filename in tqdm_notebook(os.listdir(preprocessed_tweets_filepath)):
    company_name = filename.split('.')[0]
    dates_to_tweets = {}
    for tweet_filename in os.listdir(preprocessed_tweets_filepath + '/' + filename):
        with open(preprocessed_tweets_filepath + '/' + filename + '/' + tweet_filename) as file:
            list_of_tweets = []
            for line in file:
                tweet_json = json.loads(line)
                list_of_tweets.append(tweet_json)
            dates_to_tweets[tweet_filename] = list_of_tweets
    company_to_tweets[company_name] = dates_to_tweets
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=87.0), HTML(value='')))

# %%
#print(company_to_tweets.keys())
#print(dates_to_tweets.keys())
print(company_to_tweets['AAPL']['2015-10-02'][0])
# Out:
# {'text': ['rt', '$', 'tsla', 'hft', 'algos', 'triggered', 'buy', 'in', 'sigma-x', ',', 'crossfinder', ',', 'ats', ',', 'lx', '@', '08:28', ',', 'p', '/', 't', '245.00', 'quant', '$', 'msft', '$', 'fb', '$', 'gpro', '$', 'amzn', '$', 'goog', '$', 'aapl', '$', 'nflx', '$', 'qqq'], 'created_at': 'Fri Oct 02 12:29:15 +0000 2015', 'user_id_str': '242469235'}

# %%
# Reduce logging output.
logging.set_verbosity(logging.ERROR)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Import the Universal Sentence Encoder's TF Hub module
def embed_useT(module):
    with tf.Graph().as_default():
        sentences = tf.placeholder(tf.string)
        embed = hub.Module(module)
        embeddings = embed(sentences)
        session = tf.train.MonitoredSession()
    return lambda x: session.run(embeddings, {sentences: x})
embed_fn = embed_useT(module_url)

# %%
# Generate embeddings
for company in tqdm_notebook(company_to_tweets.keys()):
  for date in company_to_tweets[company].keys():
    messages = []
    for j in range(len(company_to_tweets[company][date])):
      messages.append(' '.join(company_to_tweets[company][date][j]['text']))
    message_embeddings = embed_fn(messages)
    for k in range(len(company_to_tweets[company][date])):
      company_to_tweets[company][date][k]['embedding'] = list(message_embeddings[k])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=87.0), HTML(value='')))

# %%
# Create date mapping
date_universe = set()
for company in company_to_price_df.keys():
    date_universe = date_universe.union(set(company_to_price_df[company].date))
for company in company_to_tweets.keys():
    date_universe = date_universe.union(set(company_to_tweets[company].keys()))
date_universe = sorted(list(date_universe))
index_to_date = {i-5:d for i,d in enumerate(date_universe)}
date_to_index = {d:i-5 for i,d in enumerate(date_universe)}

# %%
# Calculate dimensions for tensor
n_stocks = len(company_to_tweets.keys())
n_days = len(date_universe)
max_tweets = 0
for c,d in itertools.product(company_to_tweets.keys(), date_universe):
    if d in company_to_tweets[c]:
        max_tweets = max(max_tweets, len(company_to_tweets[c][d]))
# Create index mapping for stocks alphabetically
company_to_index = {c:i for i,c in enumerate(sorted(list(company_to_tweets.keys())))}
# print dimensions
print(n_stocks)
print(n_days)
print(max_tweets)
# Out:
# 87
# 1473
# 555

# %%
n_days = 6

# %%
# Construct tensors
price_tensor = np.zeros((n_stocks, n_days - 5, 6, 3))
smi_tensor = np.zeros((n_stocks, n_days - 5, 6, max_tweets, 512))

# %%
# SMI tensor
for company in tqdm_notebook(company_to_price_df.keys()):
    dates = sorted(list(company_to_price_df[company].date))
    lags = []
    for date in dates[:5]:
        entry = []
        row = company_to_price_df[company].loc[company_to_price_df[company]['date'] == date]
        entry.append(row['high'].values[0])
        entry.append(row['low'].values[0])
        entry.append(row['adjust_close'].values[0])
        lags.append(entry)
    for date in dates[5:6]:
        entry = []
        row = company_to_price_df[company].loc[company_to_price_df[company]['date'] == date]
        entry.append(row['high'].values[0])
        entry.append(row['low'].values[0])
        entry.append(row['adjust_close'].values[0])
        lags.append(entry)
        company_index = company_to_index[company]
        date_index = date_to_index[date]
        date_index = 0
        for i,entry in enumerate(lags):
            for j,price in enumerate(entry):
                #stocks, day, lags, hi/lo/close
                price_tensor[company_index, date_index, i, j] = price
        lags.pop(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=87.0), HTML(value='')))

# %%
# SMI tensor
for company in tqdm_notebook(company_to_tweets.keys()):
    dates = sorted(list(company_to_tweets[company].keys()))
    lags = []
    for date in dates[:5]:
        n_tweets = len(company_to_tweets[company][date])
        lags.append([company_to_tweets[company][date][k]['embedding'] for k in range(n_tweets)])
    for date in dates[5:6]:
        n_tweets = len(company_to_tweets[company][date])
        lags.append([company_to_tweets[company][date][k]['embedding'] for k in range(n_tweets)])
        company_index = company_to_index[company]
        date_index = date_to_index[date]
        date_index = 0
        for i,messages in enumerate(lags):
            for j,embedding in enumerate(messages):
                #stocks, day, lags, tweet, embedding
                smi_tensor[company_index, date_index, i, j, :] = embedding[:]
        lags.pop(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=87.0), HTML(value='')))

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %%
price_tensor = torch.from_numpy(price_tensor)
smi_tensor = torch.from_numpy(smi_tensor)

price_tensor = price_tensor.type(torch.FloatTensor)
smi_tensor = smi_tensor.type(torch.FloatTensor)

price_tensor = price_tensor.to(device)
smi_tensor = smi_tensor.to(device)

# %%
p = price_tensor.view(n_stocks, 6, 3)

# %%
smi_tensor = smi_tensor.view(n_stocks, 6, max_tweets, 512)

smi_tensor = smi_tensor.permute(1, 0, 2, 3)

m = []
for t in range(6):
    m.append(smi_tensor[t])

# %%
neighborhoods = []
for i in range(n_stocks):
    if i % 2 == 0:
        neighborhood = [i]
        #neighborhood = [i, i + 1]
        neighborhood = torch.tensor(neighborhood)
        neighborhood = neighborhood.to(device)
        neighborhoods.append(neighborhood)
    else:
        neighborhood = [i]
        #neighborhood = [i - 1, i]
        neighborhood = torch.tensor(neighborhood)
        neighborhood = neighborhood.to(device)
        neighborhoods.append(neighborhood)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-51b5027e4711> in <module>()
#       5         #neighborhood = [i, i + 1]
#       6         neighborhood = torch.tensor(neighborhood)
# ----> 7         neighborhood = neighborhood.to(device)
#       8         neighborhoods.append(neighborhood)
#       9     else:
#
# RuntimeError: CUDA error: device-side assert triggered

# %%
mansf = MANSF(T=6,
              num_stocks=n_stocks,
              gru_hidden_size=64,
              attn_inter_size=32,
              use_embed_size=512,
              blend_size=32,
              gat_1_inter_size=32,
              gat_2_inter_size=32,
              leakyrelu_slope=0.01,
              elu_alpha=1.0,
              U=8)

# %%
mansf = mansf.to(device)

# %%
y = mansf(p, m, neighborhoods)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-6f9eea95d9a1> in <module>()
# ----> 1 y = mansf(p, m, neighborhoods)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-8-2115d0db78ac> in forward(self, p, m, neighborhoods)
#     104             for i in range(1, self.num_stocks):
#     105                 sgat = self.mgat_1[u][i]
# --> 106                 z_u_i = sgat(Wx, neighborhoods, i)
#     107                 z_u_i = self.elu(z_u_i)
#     108                 z_u = torch.cat((z_u, z_u_i), 0)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-7-951216b5dac0> in forward(self, input, neighborhoods, index)
#      18         stack_neighbors = input[neighborhood]
#      19         cat_stock = torch.cat((stack_stock, stack_neighbors), dim=1)
# ---> 20         attention_weights = self.softmax(self.leakyrelu(self.linear(cat_stock)))  # check this
#      21         output_features = torch.mm(attention_weights.T, stack_neighbors)  # check this
#      22
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/activation.py in forward(self, input)
#    1198
#    1199     def forward(self, input: Tensor) -> Tensor:
# -> 1200         return F.softmax(input, self.dim, _stacklevel=5)
#    1201
#    1202     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in softmax(input, dim, _stacklevel, dtype)
#    1581         dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1582     if dtype is None:
# -> 1583         ret = input.softmax(dim)
#    1584     else:
#    1585         ret = input.softmax(dim, dtype=dtype)
#
# RuntimeError: CUDA error: device-side assert triggered

# %%
print(y)  # initial predictions without training

# %%
Y = torch.zeros(n_stocks, 1)

for i in range(n_stocks):
    if p[i][5][2] > 0:
        Y[i][0] = 1.0

# %%
Y = Y.to(device)

# %%
optimizer = optim.Adam(mansf.parameters())
loss_fn = nn.BCELoss()

# %%
for epoch in range(100):
    mansf.train()
    y = mansf(p, m, neighborhoods)
    loss = loss_fn(y.view(-1), Y.view(-1))
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    print(epoch, loss)

# %%
print(y)

# %%
ycatY = torch.cat((y, Y), dim=1)

# %%
print(ycatY)

# %%
print(Y)

# %% [markdown]
# #Testing

# %%
p = torch.tensor([[[1.5, 1.8, 1.2], [1.7, 1.9, 1.3]], [[0.8, 0.9, 0.6], [0.6, 0.7, 0.4]]])

# %%
print(p.shape)

# %%
m = [torch.zeros(2,1,64),torch.zeros(2,1,64)]

# %%
print(m[0].shape)

# %%
neighborhoods = [[0,1],[0,1,]]

# %%
Y = torch.tensor([[1.0],[0.0]])

# %%
print(Y.shape)

# %%
mansf = MANSF(T=2,
              num_stocks=2,
              gru_hidden_size=64,
              attn_inter_size=32,
              use_embed_size=64,
              blend_size=32,
              gat_1_inter_size=32,
              gat_2_inter_size=32,
              leakyrelu_slope=0.01,
              elu_alpha=1.0,
              U=8)

# %%
y = mansf(p, m, neighborhoods)

# %%
print(y)  # initial predictions without training

# %%
optimizer = optim.Adam(mansf.parameters())
loss_fn = nn.BCELoss()

for epoch in range(100):
    mansf.train()
    y = mansf(p, m, neighborhoods)
    loss = loss_fn(y.view(-1), Y.view(-1))
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    print(y[0].item(), y[1].item())

# %%
print(y)

# %%
p_test = torch.tensor([[[1.3, 1.6, 1.0], [1.4, 1.5, 1.2]], [[0.83, 0.91, 0.67], [0.75, 0.89, 0.56]]])

# %%
m_test = [torch.zeros(2,1,64),torch.zeros(2,1,64)]

# %%
y_test = mansf(p_test, m_test, neighborhoods)

# %%
print(y_test)

# %%
p_test2 = torch.tensor([[[0.83, 0.91, 0.67], [0.75, 0.89, 0.56]], [[1.3, 1.6, 1.0], [1.4, 1.5, 1.2]]])

# %%
m_test2 = [torch.zeros(2,1,64),torch.zeros(2,1,64)]

# %%
y_test2 = mansf(p_test2, m_test2, neighborhoods)

# %%
print(y_test2)

# %% [markdown]
# #Sandbox

# %% [markdown]
# ##Price Encoding

# %%
T = 5  # number of days in lookback window
batch_size = 4
gru_p_hidden_size = 64

p = torch.rand(batch_size, T, 3)  # p_i = [p_i^c, p_i^h, p_i^l], not bothering to normalize for shape tests

print('p.shape', p.shape)

h_p_0 = torch.randn(1, batch_size, gru_p_hidden_size)  # randomly initialized initial hidden state
gru_p = GRU(3, gru_p_hidden_size, batch_first=True)

h_p, h_p_n = gru_p(p, h_p_0)

print('h_p.shape', h_p.shape)
print('h_p_n.shape', h_p_n.shape)

# %%
attn_p_intermediate_size = 10

attn_p = LinearAttention(gru_p_hidden_size, attn_p_intermediate_size, 1)

q = attn_p(h_p)

print('q.shape', q.shape)

# %% [markdown]
# ##SMI Encoding

# %%
K = [7, 9, 11, 13, 15]  # number of tweets for each day in lookback window
T = 5  # number or days in lookback window
batch_size = 4
gru_m_hidden_size = 64
use_embedding_size = 512

r = torch.zeros(batch_size, 0, gru_m_hidden_size)

gru_m = GRU(use_embedding_size, gru_m_hidden_size, batch_first=True)

for t in range(T):

    m = torch.rand(batch_size, K[0], use_embedding_size)

    print('m.shape', m.shape)

    h_m_0 = torch.randn(1, batch_size, gru_m_hidden_size)  # randomly initialized initial hidden state

    h_m, h_m_n = gru_m(m, h_m_0)

    print('h_m.shape', h_m.shape)
    print('h_m_n.shape', h_m_n.shape)

    attn_m_intermediate_size = 10

    attn_m = LinearAttention(gru_m_hidden_size, attn_m_intermediate_size, 1)

    r_t = attn_m(h_m)

    print('r_t.shape', r_t.shape)

    r = torch.cat((r, r_t), 1)

    print('r.shape', r.shape)

    print()

# %%
gru_s_hidden_size = 64

print('r.shape', r.shape)

h_s_0 = torch.randn(1, batch_size, gru_s_hidden_size)  # randomly initialized initial hidden state
gru_s = GRU(gru_m_hidden_size, gru_s_hidden_size, batch_first=True)

h_s, h_s_n = gru_s(r, h_s_0)

print('h_s.shape', h_s_0.shape)
print('h_s_n.shape', h_s_n.shape)

# %%
attn_s_intermediate_size = 10

attn_s = LinearAttention(gru_s_hidden_size, attn_s_intermediate_size, 1)

c = attn_s(h_s)

print('c.shape', c.shape)

# %% [markdown]
# ##Blending

# %%
blend_size = 9

# %%
blend = Blend(q.shape[2], c.shape[2], blend_size)

# %%
x = blend(q, c)

# %%
print('x.shape', x.shape)

# %%
num_stocks = x.shape[0]

# %%
x = x.view(x.shape[0], x.shape[2])

# %%
print('x.shape', x.shape)

# %% [markdown]
# ##GAT

# %%
intermediate_size = 5

# %%
nhoods = [[0,1], [0,1,2], [1,2], [3]]

# %%
shared_linear = SharedLinear(blend_size, intermediate_size)

# %%
Wx = shared_linear(x)

# %%
print('Wx.shape', Wx.shape)

# %% [markdown]
# ##MGAT 1

# %%
U = 8

# %%
elu = nn.ELU()

# %%
sgat = SGAT(intermediate_size, 1)

z = sgat(Wx, nhoods, 0)

z = elu(z)

for i in range(1, num_stocks):
    z_i = sgat(Wx, nhoods, i)
    z_i = elu(z_i)
    z = torch.cat((z, z_i), 0)

for u in range(1, U):
    sgat = SGAT(intermediate_size, 1)

    z_u = sgat(Wx, nhoods, 0)

    z_u = elu(z_u)

    for i in range(1, num_stocks):
        z_u_i = sgat(Wx, nhoods, i)
        z_u_i = elu(z_u_i)
        z_u = torch.cat((z_u, z_u_i), 0)
    
    z = torch.cat((z, z_u), 1)

# %%
print('z.shape', z.shape)

# %% [markdown]
# ##MGAT 2

# %%
U = 8

# %%
sigmoid = nn.Sigmoid()

# %%
new_intermediate_size = 11

# %%
shared_linear = SharedLinear(z.shape[1], new_intermediate_size)

# %%
Wx = shared_linear(z)

# %%
print('Wx.shape', Wx.shape)

# %%
sgat = SGAT(new_intermediate_size, 1)

z = sgat(Wx, nhoods, 0)

z = sigmoid(z)

for i in range(1, num_stocks):
    z_i = sgat(Wx, nhoods, i)
    z_i = sigmoid(z_i)
    z = torch.cat((z, z_i), 0)

for u in range(1, U):
    sgat = SGAT(new_intermediate_size, 1)

    z_u = sgat(Wx, nhoods, 0)

    z_u = sigmoid(z_u)

    for i in range(1, num_stocks):
        z_u_i = sgat(Wx, nhoods, i)
        z_u_i = sigmoid(z_u_i)
        z_u = torch.cat((z_u, z_u_i), 0)
    
    z = torch.cat((z, z_u), 1)

# %%
print('z.shape', z.shape)

# %% [markdown]
# ##Final Layer

# %%
linear = nn.Linear(z.shape[1], 1, bias=True)
sigmoid = nn.Sigmoid()

# %%
sigmoid(linear(z))

# %%
print(sigmoid(linear(z)).shape)
